# %%
import numpy as np

'''
There are 4 types of arrays

1. zero dimensional array --  store only single value
2. Single dimensional array -- store multiple values
3. Two dimensional array --- store the values in matrix format
4. multidimensional arrat

'''
# create zero dimensional array

arr = np.array(10)
print(arr.ndim) # to print dimension of an array
