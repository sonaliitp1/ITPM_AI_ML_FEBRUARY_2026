# %%
import pandas as pd 
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

import pandas as pd 

data = pd.DataFrame({
    "height":[64,70,72,68,76],
    "salary":[45000,67897,34567,67432,90000]
})

model = StandardScaler()

new_array = model.fit_transform(data)

print(new_array.round(1))
# Out:
# [[-1.5 -0.8]
#  [ 0.   0.4]
#  [ 0.5 -1.4]
#  [-0.5  0.3]
#  [ 1.5  1.5]]
