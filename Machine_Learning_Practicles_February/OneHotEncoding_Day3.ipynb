# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame({
    "name":["John","Blake","Scott","Martin","Joe"],
    "color":["Red","Green","Blue","Red","Green"]
})

# Performing OneHot Encoding(create binary columns matrix)
encoded = pd.get_dummies(data["color"],dtype=int)

print(encoded)
# Out:
#    Blue  Green  Red
# 0     0      0    1
# 1     0      1    0
# 2     1      0    0
# 3     0      0    1
# 4     0      1    0
