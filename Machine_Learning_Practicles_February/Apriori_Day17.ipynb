# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# 1. Create transactions
transactions = [
    ["Milk", "Bread"],
    ["Milk", "Bread", "Butter"],
    ["Bread", "Butter"],
    ["Milk", "Bread", "Butter"],
    ["Milk", "Bread"]
]

# %%
# 2. Convert transactions into DataFrame
te = TransactionEncoder()
data = te.fit(transactions).transform(transactions)

df = pd.DataFrame(data, columns=te.columns_)

print("Transaction Data:")
print(df)
# Out:
# Transaction Data:
#    Bread  Butter   Milk
# 0   True   False   True
# 1   True    True   True
# 2   True    True  False
# 3   True    True   True
# 4   True   False   True

# %%
# 3. Find frequent itemsets
frequent_items = apriori(
    df,
    min_support=0.4,
    use_colnames=True
)

# %%
print("\nFrequent Itemsets:")
print(frequent_items)
# Out:
# Frequent Itemsets:
#    support                          itemsets
# 0      1.0                frozenset({Bread})
# 1      0.6               frozenset({Butter})
# 2      0.8                 frozenset({Milk})
# 3      0.6        frozenset({Butter, Bread})
# 4      0.8          frozenset({Milk, Bread})
# 5      0.4         frozenset({Butter, Milk})
# 6      0.4  frozenset({Butter, Milk, Bread})

# %%
# 4. Generate association rules
rules = association_rules(
    frequent_items,
    metric="confidence",
    min_threshold=0.6
)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:184: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)

# %%
# 5. Display useful columns
print("\nAssociation Rules:")
print(rules[[
    "antecedents",
    "consequents",
    "support",
    "confidence",
    "lift"
]])
# Out:
# Association Rules:
#                   antecedents               consequents  support  confidence  \
# 0         frozenset({Butter})        frozenset({Bread})      0.6    1.000000
# 1          frozenset({Bread})       frozenset({Butter})      0.6    0.600000
# 2           frozenset({Milk})        frozenset({Bread})      0.8    1.000000
# 3          frozenset({Bread})         frozenset({Milk})      0.8    0.800000
# 4         frozenset({Butter})         frozenset({Milk})      0.4    0.666667
# 5   frozenset({Butter, Milk})        frozenset({Bread})      0.4    1.000000
# 6  frozenset({Butter, Bread})         frozenset({Milk})      0.4    0.666667
# 7         frozenset({Butter})  frozenset({Milk, Bread})      0.4    0.666667
#
#        lift
# 0  1.000000
# 1  1.000000
# 2  1.000000
# 3  1.000000
# 4  0.833333
# 5  1.000000
# 6  0.833333
# 7  0.833333
